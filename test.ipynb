# %%
import pandas
import seaborn as sns

# To analyze orbital dynamics effectively, we need these orbital and physical parameters:
identifier_params = [
    'full_name',  # Full designation
    'spkid',     # SPK ID
    'neo',        # Near-Earth Object flag
    'pha',        # Potentially Hazardous Asteroid flag
]

crucial_orbital_params = [
    'a',        # Semi-major axis (AU)
    'e',        # Eccentricity
    'i',        # Inclination (deg)
    'q',        # Perihelion distance (AU)
    'ad',       # Aphelion distance (AU)
    'per',      # Orbital period (years)
    'n',        # Mean motion (deg/day)
    'ma',       # Mean anomaly (deg)
]

physical_properties = [
    'H',        # Absolute magnitude (size proxy)
    'diameter', # Diameter (km) - when available
    'albedo',   # Geometric albedo
    'rot_per',  # Rotation period (hours)
    'GM',       # Mass parameter (rare but valuable)
    'spec_B',   # Spectral type (Bus/Tholen)
    'spec_T',   # Taxonomic class
]


# Non-essential data but useful for assessing data quality later down the line
quality_metrics = [
    'condition_code',  # Orbit uncertainty (0-9, 0=best)
    'n_obs_used',      # Number of observations
    'data_arc',        # Observation span (days)
    'first_obs',       # First observation date
    'last_obs',        # Last observation date
]

# %%
import requests

def query_jpl_sbdb(include_quality_metrics=False):
    base_url = "https://ssd-api.jpl.nasa.gov/sbdb_query.api"
    results = []
    fields_str = identifier_params + crucial_orbital_params + physical_properties + (quality_metrics if include_quality_metrics else [])
    print(','.join(fields_str))

    params = {
        'fields': ','.join(fields_str),
        'limit': 100  # Limit the number of results
    }
    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        results.append(response.json())
    else:
        print(f"Error: {response.status_code} - {response.text}")
    
    return results

# %%
jpl_data = query_jpl_sbdb()
# Out:
# full_name,spkid,neo,pha,a,e,i,q,ad,per,n,ma,H,diameter,albedo,rot_per,GM,spec_B,spec_T

# %%
# pandas.DataFrame(jpl_data)
df = pandas.json_normalize(jpl_data, record_path=['data'])

# set column names from jpl_data[0]['fields'] if present
fields = jpl_data[0].get('fields') if isinstance(jpl_data, list) and jpl_data else None
if fields:
    if len(fields) == len(df.columns):
        df.columns = fields
    else:
        # align/truncate if lengths differ
        df.columns = fields[:len(df.columns)]
df.head()
# Out:
#                   full_name     spkid neo pha      a       e      i      q  \
# 0         1 Ceres (A801 AA)  20000001   N   N  2.766  0.0796  10.59  2.546
# 1        2 Pallas (A802 FA)  20000002   N   N   2.77  0.2306  34.93  2.131
# 2          3 Juno (A804 RA)  20000003   N   N  2.671  0.2558  12.99  1.988
# 3         4 Vesta (A807 FA)  20000004   N   N  2.362  0.0902   7.14  2.149
# 4       5 Astraea (A845 XA)  20000005   N   N  2.577  0.1875   5.36  2.094
#
#      ad       per       n      ma     H diameter  albedo       rot_per  \
# 0  2.99  1.68e+03  0.2143  231.54  3.35    939.4   0.090      9.074170
# 1  3.41  1.68e+03  0.2138  211.53  4.11      513   0.155     7.8132214
# 2  3.35  1.59e+03  0.2258  217.59  5.19  246.596   0.214          7.21
# 3  2.57  1.33e+03  0.2716   26.81  3.25   522.77  0.4228  5.3421276322
# 4  3.06  1.51e+03  0.2383  133.87  6.97  106.699   0.274        16.806
#
#            GM spec_B spec_T
# 0     62.6284      C      G
# 1       13.63      B      B
# 2        None     Sk      S
# 3  17.2882844      V      V
# 4        None      S      S

# %%
# Now let's clean that data from Gaia (`tableb1.dat`)
# CSV headers converted from the fixed-width spec for tableb1.dat

csv_headers = [
    'Asteroid',   # Name of the asteroid
    'H',          # Absolute magnitude (mag)
    'RMS',        # RMS of normalized residuals, 7D OD
    'RMS6D',      # RMS of normalized residuals, 6D OD
    'A2',         # Transversal acceleration component (au/d2)
    'e_A2',       # Error in A2 (au/d2)
    'da_dt',      # Semi-major axis drift (au/Myr)
    'e_da_dt',    # Error in da/dt (au/Myr)
    'max_da_dt',  # Maximum da/dt from Monte Carlo model (au/Myr)
    'SNR',        # Signal-to-noise of A2 detection
    'FAccept',    # [1 Rej.] Flag for acceptance of the detection
    'NOptObs',    # Number of optical observations
    'NRejOpt',    # Number of rejected optical observations in 7D OD
    'NRej6D',     # Number of rejected optical observations in 6D OD
    'NRadObs',    # Number of radar observations
    'NRejRad',    # Number of rejected radar obs in 7D OD
    'NRejRad6D',  # Number of rejected radar obs in 6D OD
    'NOptOld',    # Number of old observations
    'Dlow',       # 15-th percentile of diameter (m)
    'Dmed',       # 50-th percentile of diameter (m)
    'Dhigh',      # 85-th percentile of diameter (m)
    'ModFlag',    # [0/1] Flag for model used in Monte Carlo
    'Prot',       # Rotation period of the asteroid (h), ?=-1 if unknown
    'Tax',        # Taxonomic complex of the asteroid
    'deltat'      # Length of observational arc (yr)
]
# Out:
# Asteroid,H,RMS,RMS6D,A2,e_A2,da_dt,e_da_dt,max_da_dt,SNR,FAccept,NOptObs,NRejOpt,NRej6D,NRadObs,NRejRad,NRejRad6D,NOptOld,Dlow,Dmed,Dhigh,ModFlag,Prot,Tax,deltat

# %%
# Now let's load that data from Gaia (`tableb1.dat`)

# `names` must be a list of column names (use csv_headers), and explicitly set header=None

gaia_data = pandas.read_fwf(
	'./confirmed_yark_dataset/tableb1.dat',
	colspecs='infer',
)
gaia_data.columns = csv_headers
gaia_data.head()

gaia_data
# Out:
#       Asteroid       H       RMS     RMS6D            A2          e_A2  \
# 0     1998 SD9  23.918  0.788754  6.841540 -2.898460e-13  1.564160e-15
# 1        99942  18.945  0.307869  0.336636 -2.888940e-14  2.350760e-16
# 2       480883  20.900  0.472885  2.486020 -6.918980e-14  7.312950e-16
# 3         2340  20.437  0.728716  0.759563 -2.998710e-14  5.250600e-16
# 4       524522  20.530  0.463988  1.099570 -5.983760e-14  1.051020e-15
# ..         ...     ...       ...       ...           ...           ...
# 457  2005 NE21  21.268  0.587481  0.615949  5.852140e-14  1.938950e-14
# 458     152664  19.669  0.478537  0.486609  1.623280e-14  5.381410e-15
# 459       7336  18.789  0.464234  0.469641  3.145140e-14  1.043840e-14
# 460     162416  21.330  0.585074  0.489558  1.559140e-11  5.182290e-12
# 461  1999 SF10  24.212  0.575818  0.641836  8.117100e-13  2.704970e-13
#
#         da_dt   e_da_dt  max_da_dt        SNR  ... NRejRad  NRejRad6D  \
# 0   -0.019706  0.000106   0.031790  185.30500  ...       0          0
# 1   -0.001326  0.000011   0.002811  122.89400  ...       0          5
# 2   -0.005045  0.000053   0.011612   94.61270  ...       0          2
# 3   -0.001738  0.000030   0.008028   57.11180  ...       0          0
# 4   -0.003592  0.000063   0.004257   56.93290  ...       0          7
# ..        ...       ...        ...        ...  ...     ...        ...
# 457  0.003712  0.001230   0.008357    3.01820  ...       0          0
# 458  0.000907  0.000301   0.004420    3.01645  ...       0          0
# 459  0.001143  0.000379   0.002218    3.01305  ...       0          0
# 460  0.630594  0.209598   0.006902    3.00859  ...       0          0
# 461  0.032566  0.010853   0.008900    3.00081  ...       0          0
#
#      NOptOld     Dlow    Dmed    Dhigh  ModFlag   Prot  Tax  deltat
# 0         27   25.295   35.41   75.886        1  -1.00    N  19.992
# 1          0  300.000  340.00  380.000        0  27.38    N  17.180
# 2          0  103.673  172.78  287.979        1  -1.00    V  20.085
# 3         92  134.014  193.57  312.700        1   3.35    Q  45.120
# 4          0  112.383  176.60  337.150        1  13.43    N  16.060
# ..       ...      ...     ...      ...      ...    ...  ...     ...
# 457        0  102.221  147.65  261.232        1  -1.00    S  14.007
# 458       40  225.018  353.59  739.343        1  17.38    Q  27.910
# 459      203  273.707  430.11  742.918        1   3.36    Q  35.239
# 460        0  116.000  141.00  166.000        0  -1.00    N   5.322
# 461       52   21.895   36.49   60.820        1   0.04    N  13.196
#
# [462 rows x 25 columns]

# %%
# Let's get clean names or IAU designations from the Gaia dataset
gaia_names = gaia_data['Asteroid'].tolist()

# %%
f = open("names", "w")
for name in gaia_names:
    f.write(name + "\n")
f.close()

# %%
import requests
import time
import json

def fetch_asteroid_data(designation):
    """Fetches complete data for an asteroid, including physical parameters."""
    url = "https://ssd-api.jpl.nasa.gov/sbdb.api"
    params = {
        'sstr': designation,
        'phys-par': 1  # Essential to get physical properties
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raises an exception for bad status codes
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

f = open("names", "r")
read_list = f.readlines()
f.close()

for designation in read_list[200:300]:
    data = fetch_asteroid_data(designation)
    print(json.dumps(data, indent=2))
    time.sleep(1)  # Be polite to the API
    if not data:
        continue

    obj = data.get('object') or {}
    if not obj:
        print(f"No 'object' block for {designation}, skipping.")
        continue

    # write the raw "object" JSON to file (one JSON object per line)
    with open('asteroid_mapping.txt', 'a') as f:
        f.write(json.dumps(obj) + '\n')

    print(f"Wrote raw object for {designation}: spkid={obj.get('spkid')}, des={obj.get('des')}")
# Out:
# {
#   "orbit": {
#     "sb_used": "SB441-N16",
#     "first_obs": "1998-09-18",
#     "source": "JPL",
#     "epoch": "2461000.5",
#     "moid": "0.00859",
#     "orbit_id": "29",
#     "two_body": null,
#     "moid_jup": "3.91",
#     "n_del_obs_used": 1,
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "data_arc": "7302",
#     "rms": "0.43",
#     "n_dop_obs_used": 0,
#     "soln_date": "2022-12-20 14:10:52",
#     "producer": "Otto Matic",
#     "not_valid_before": null,
#     "not_valid_after": null,
#     "equinox": "J2000",
#     "elements": [
#       {
#         "name": "e",
#         "label": "e",
#         "sigma": "8.3e-08",
#         "units": null,
#         "value": "0.504",
#         "title": "eccentricity"
#       },
#       {
#         "title": "semi-major axis",
#         "value": "0.702",
#         "units": "au",
#         "sigma": "3.1e-09",
#         "label": "a",
#         "name": "a"
#       },
#       {
#         "sigma": "5.8e-08",
#         "units": "au",
#         "title": "perihelion distance",
#         "value": "0.348",
#         "name": "q",
#         "label": "q"
#       },
#       {
#         "units": "deg",
#         "sigma": "7.4e-06",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "value": "2.99",
#         "name": "i",
#         "label": "i"
#       },
#       {
#         "name": "om",
#         "label": "node",
#         "sigma": "2.2e-05",
#         "units": "deg",
#         "title": "longitude of the ascending node",
#         "value": "166"
#       },
#       {
#         "name": "w",
#         "label": "peri",
#         "units": "deg",
#         "sigma": "2.6e-05",
#         "title": "argument of perihelion",
#         "value": "7.7"
#       },
#       {
#         "units": "deg",
#         "sigma": "3.8e-05",
#         "title": "mean anomaly",
#         "value": "233",
#         "name": "ma",
#         "label": "M"
#       },
#       {
#         "sigma": "2.3e-05",
#         "units": "TDB",
#         "title": "time of perihelion passage",
#         "value": "2461076.340",
#         "name": "tp",
#         "label": "tp"
#       },
#       {
#         "label": "period",
#         "name": "per",
#         "title": "sidereal orbital period",
#         "value": "215",
#         "units": "d",
#         "sigma": "1.4e-06"
#       },
#       {
#         "value": "1.67",
#         "title": "mean motion",
#         "units": "deg/d",
#         "sigma": "1.1e-08",
#         "label": "n",
#         "name": "n"
#       },
#       {
#         "name": "ad",
#         "label": "Q",
#         "sigma": "4.7e-09",
#         "units": "au",
#         "value": "1.06",
#         "title": "aphelion distance"
#       }
#     ],
#     "model_pars": [
#       {
#         "desc": "non-gravitational transverse acceleration parameter",
#         "title": "non-grav. transverse accel.",
#         "units": "au/d^2",
#         "kind": "EST",
#         "name": "A2",
#         "n": 1,
#         "value": "-2.872e-13",
#         "sigma": "2.626E-15"
#       },
#       {
#         "name": "ALN",
#         "kind": "SET",
#         "value": "1.",
#         "n": 0,
#         "sigma": null,
#         "desc": "normalizing factor [default 0.1112620426]",
#         "title": "normalizing factor",
#         "units": null
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "title": "non-grav. model exp. k",
#         "units": null,
#         "name": "NK",
#         "kind": "SET",
#         "n": 0,
#         "value": "0.",
#         "sigma": null
#       },
#       {
#         "units": null,
#         "title": "non-grav. model exp. m",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "sigma": null,
#         "value": "2.",
#         "n": 0,
#         "name": "NM",
#         "kind": "SET"
#       },
#       {
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "units": "au",
#         "title": "normalizing distance",
#         "name": "R0",
#         "kind": "SET",
#         "sigma": null,
#         "n": 0,
#         "value": "1."
#       }
#     ],
#     "cov_epoch": "2458112.5",
#     "condition_code": "0",
#     "pe_used": "DE441",
#     "n_obs_used": 150,
#     "last_obs": "2018-09-15",
#     "t_jup": "8.041"
#   },
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   },
#   "phys_par": [
#     {
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "ref": "E2021T29",
#       "units": null,
#       "title": "absolute magnitude",
#       "name": "H",
#       "sigma": null,
#       "value": "24.09",
#       "notes": null
#     }
#   ],
#   "object": {
#     "prefix": null,
#     "des": "1998 SD9",
#     "kind": "au",
#     "fullname": "(1998 SD9)",
#     "spkid": "3014184",
#     "pha": false,
#     "orbit_id": "29",
#     "neo": true,
#     "orbit_class": {
#       "code": "ATE",
#       "name": "Aten"
#     }
#   }
# }
# Wrote raw object for 1998 SD9
# : spkid=3014184, des=1998 SD9
# {
#   "orbit": {
#     "not_valid_after": null,
#     "condition_code": "0",
#     "two_body": null,
#     "first_obs": "2004-03-15",
#     "n_obs_used": 7370,
#     "rms": "0.26",
#     "n_dop_obs_used": 30,
#     "comment": null,
#     "t_jup": "6.466",
#     "producer": "Davide Farnocchia",
#     "orbit_id": "220",
#     "epoch": "2461000.5",
#     "moid_jup": "4.12",
#     "sb_used": "SB441-N16",
#     "not_valid_before": null,
#     "elements": [
#       {
#         "label": "e",
#         "name": "e",
#         "title": "eccentricity",
#         "sigma": "1.3e-09",
#         "value": "0.191",
#         "units": null
#       },
#       {
#         "units": "au",
#         "value": "0.922",
#         "sigma": "2.4e-09",
#         "name": "a",
#         "title": "semi-major axis",
#         "label": "a"
#       },
#       {
#         "sigma": "1.6e-09",
#         "units": "au",
#         "value": "0.746",
#         "label": "q",
#         "name": "q",
#         "title": "perihelion distance"
#       },
#       {
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i",
#         "label": "i",
#         "value": "3.34",
#         "units": "deg",
#         "sigma": "9.9e-08"
#       },
#       {
#         "title": "longitude of the ascending node",
#         "name": "om",
#         "label": "node",
#         "units": "deg",
#         "value": "204",
#         "sigma": "3.1e-06"
#       },
#       {
#         "sigma": "3.4e-06",
#         "value": "127",
#         "units": "deg",
#         "label": "peri",
#         "name": "w",
#         "title": "argument of perihelion"
#       },
#       {
#         "value": "313",
#         "units": "deg",
#         "sigma": "8.3e-07",
#         "title": "mean anomaly",
#         "name": "ma",
#         "label": "M"
#       },
#       {
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp",
#         "value": "2461042.918",
#         "units": "TDB",
#         "sigma": "6.2e-07"
#       },
#       {
#         "label": "period",
#         "title": "sidereal orbital period",
#         "name": "per",
#         "sigma": "1.3e-06",
#         "units": "d",
#         "value": "324"
#       },
#       {
#         "sigma": "4.4e-09",
#         "units": "deg/d",
#         "value": "1.11",
#         "label": "n",
#         "name": "n",
#         "title": "mean motion"
#       },
#       {
#         "title": "aphelion distance",
#         "name": "ad",
#         "label": "Q",
#         "units": "au",
#         "value": "1.1",
#         "sigma": "2.9e-09"
#       }
#     ],
#     "pe_used": "DE441",
#     "soln_date": "2024-06-25 10:48:08",
#     "moid": "0.000361",
#     "data_arc": "6599",
#     "last_obs": "2022-04-09",
#     "model_pars": [
#       {
#         "desc": "non-gravitational radial acceleration parameter",
#         "value": "5e-13",
#         "kind": "EST",
#         "title": "non-grav. radial accel.",
#         "n": 1,
#         "sigma": "4.892E-13",
#         "units": "au/d^2",
#         "name": "A1"
#       },
#       {
#         "sigma": "1.859E-16",
#         "units": "au/d^2",
#         "name": "A2",
#         "desc": "non-gravitational transverse acceleration parameter",
#         "value": "-2.902e-14",
#         "kind": "EST",
#         "n": 2,
#         "title": "non-grav. transverse accel."
#       },
#       {
#         "name": "ALN",
#         "units": null,
#         "sigma": null,
#         "title": "normalizing factor",
#         "n": 0,
#         "kind": "SET",
#         "value": "1.",
#         "desc": "normalizing factor [default 0.1112620426]"
#       },
#       {
#         "sigma": null,
#         "units": null,
#         "name": "NK",
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "kind": "SET",
#         "n": 0,
#         "title": "non-grav. model exp. k"
#       },
#       {
#         "name": "NM",
#         "units": null,
#         "sigma": null,
#         "n": 0,
#         "title": "non-grav. model exp. m",
#         "kind": "SET",
#         "value": "2.",
#         "desc": "non-grav. model constant, exponent m [default 2.15]"
#       },
#       {
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "value": "1.",
#         "kind": "SET",
#         "n": 0,
#         "title": "normalizing distance",
#         "sigma": null,
#         "units": "au",
#         "name": "R0"
#       }
#     ],
#     "cov_epoch": "2459215.5",
#     "n_del_obs_used": 20,
#     "equinox": "J2000",
#     "source": "JPL"
#   },
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "phys_par": [
#     {
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "ref": "Pravec et al., Icarus 233, 48-60 (2014)",
#       "value": "19.09",
#       "notes": null,
#       "title": "absolute magnitude",
#       "sigma": "0.19",
#       "units": null,
#       "name": "H"
#     },
#     {
#       "desc": "magnitude slope parameter used in the standard asteroid H/G magnitude law",
#       "ref": "Pravec et al., Icarus 233, 48-60 (2014)",
#       "value": "0.24",
#       "notes": "Assumed based on Warner et al., Icarus 202, 1340146 (2009)",
#       "title": "magnitude slope",
#       "sigma": "0.11",
#       "units": null,
#       "name": "G"
#     },
#     {
#       "notes": "Based on 3D shape model derived from radar observations in 2012-2013",
#       "title": "diameter",
#       "desc": "effective body diameter",
#       "ref": "Brozovic et al., Icarus 300, 115-128 (2018)",
#       "value": "0.34",
#       "name": "diameter",
#       "sigma": "0.04",
#       "units": "km"
#     },
#     {
#       "notes": null,
#       "title": "rotation period",
#       "desc": "body rotation period (synodic)",
#       "ref": "Pravec et al., Icarus 233, 48-60 (2014)",
#       "value": "30.56",
#       "name": "rot_per",
#       "sigma": "0.01",
#       "units": "h"
#     },
#     {
#       "name": "albedo",
#       "sigma": "0.10",
#       "units": null,
#       "title": "geometric albedo",
#       "notes": null,
#       "ref": "Brozovic et al., Icarus 300, 115-128 (2018)",
#       "desc": "geometric albedo",
#       "value": "0.35"
#     },
#     {
#       "value": "50-500",
#       "ref": "Licandro et al., A&A 585, A10 (2016)",
#       "desc": "Thermal inertia of the small-body surface",
#       "title": "thermal inertia",
#       "notes": null,
#       "units": "J/m^2/s^0.5/K",
#       "sigma": null,
#       "name": "I"
#     },
#     {
#       "sigma": null,
#       "units": null,
#       "name": "spec_B",
#       "desc": "SMASSII spectral taxonomic classification",
#       "ref": "Binzel, R. P. et al.  Icarus 200 (2009) 480-485",
#       "value": "Sq",
#       "notes": null,
#       "title": "SMASSII spectral type"
#     }
#   ],
#   "object": {
#     "fullname": "99942 Apophis (2004 MN4)",
#     "kind": "an",
#     "pha": true,
#     "des": "99942",
#     "orbit_class": {
#       "code": "ATE",
#       "name": "Aten"
#     },
#     "prefix": null,
#     "neo": true,
#     "shortname": "99942 Apophis",
#     "spkid": "20099942",
#     "orbit_id": "220"
#   }
# }
# Wrote raw object for 99942
# : spkid=20099942, des=99942
# {
#   "orbit": {
#     "model_pars": [
#       {
#         "units": "au/d^2",
#         "sigma": "9.184E-16",
#         "name": "A2",
#         "value": "-6.948e-14",
#         "desc": "non-gravitational transverse acceleration parameter",
#         "n": 1,
#         "title": "non-grav. transverse accel.",
#         "kind": "EST"
#       },
#       {
#         "desc": "normalizing factor [default 0.1112620426]",
#         "value": "1.",
#         "kind": "SET",
#         "n": 0,
#         "title": "normalizing factor",
#         "sigma": null,
#         "units": null,
#         "name": "ALN"
#       },
#       {
#         "name": "NK",
#         "units": null,
#         "sigma": null,
#         "title": "non-grav. model exp. k",
#         "n": 0,
#         "kind": "SET",
#         "value": "0.",
#         "desc": "non-grav. model constant, exponent k [default 4.6142]"
#       },
#       {
#         "value": "2.",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "n": 0,
#         "title": "non-grav. model exp. m",
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "NM"
#       },
#       {
#         "name": "R0",
#         "sigma": null,
#         "units": "au",
#         "kind": "SET",
#         "n": 0,
#         "title": "normalizing distance",
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "value": "1."
#       }
#     ],
#     "cov_epoch": "2455927.5",
#     "n_del_obs_used": 6,
#     "equinox": "J2000",
#     "source": "JPL",
#     "not_valid_before": null,
#     "elements": [
#       {
#         "title": "eccentricity",
#         "name": "e",
#         "label": "e",
#         "value": "0.54",
#         "units": null,
#         "sigma": "2.4e-08"
#       },
#       {
#         "units": "au",
#         "value": "0.677",
#         "sigma": "7.4e-10",
#         "title": "semi-major axis",
#         "name": "a",
#         "label": "a"
#       },
#       {
#         "units": "au",
#         "value": "0.311",
#         "sigma": "1.6e-08",
#         "name": "q",
#         "title": "perihelion distance",
#         "label": "q"
#       },
#       {
#         "label": "i",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i",
#         "sigma": "4.3e-06",
#         "units": "deg",
#         "value": "4.85"
#       },
#       {
#         "sigma": "3.6e-05",
#         "value": "305",
#         "units": "deg",
#         "label": "node",
#         "name": "om",
#         "title": "longitude of the ascending node"
#       },
#       {
#         "sigma": "3.4e-05",
#         "value": "319",
#         "units": "deg",
#         "label": "peri",
#         "name": "w",
#         "title": "argument of perihelion"
#       },
#       {
#         "label": "M",
#         "title": "mean anomaly",
#         "name": "ma",
#         "sigma": "1e-05",
#         "value": "193",
#         "units": "deg"
#       },
#       {
#         "value": "2461094.768",
#         "units": "TDB",
#         "sigma": "5.8e-06",
#         "name": "tp",
#         "title": "time of perihelion passage",
#         "label": "tp"
#       },
#       {
#         "label": "period",
#         "title": "sidereal orbital period",
#         "name": "per",
#         "sigma": "3.3e-07",
#         "value": "203",
#         "units": "d"
#       },
#       {
#         "title": "mean motion",
#         "name": "n",
#         "label": "n",
#         "units": "deg/d",
#         "value": "1.77",
#         "sigma": "2.9e-09"
#       },
#       {
#         "sigma": "1.1e-09",
#         "value": "1.04",
#         "units": "au",
#         "label": "Q",
#         "name": "ad",
#         "title": "aphelion distance"
#       }
#     ],
#     "soln_date": "2023-09-01 06:01:38",
#     "pe_used": "DE441",
#     "moid": "0.0312",
#     "data_arc": "7336",
#     "last_obs": "2022-01-21",
#     "sb_used": "SB441-N16",
#     "moid_jup": "4.03",
#     "condition_code": "0",
#     "not_valid_after": null,
#     "first_obs": "2001-12-21",
#     "two_body": null,
#     "n_dop_obs_used": 1,
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "n_obs_used": 439,
#     "rms": "0.37",
#     "t_jup": "8.292",
#     "orbit_id": "71",
#     "producer": "Otto Matic",
#     "epoch": "2461000.5"
#   },
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "phys_par": [
#     {
#       "ref": "MPO745323",
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "value": "20.92",
#       "title": "absolute magnitude",
#       "notes": null,
#       "sigma": null,
#       "units": null,
#       "name": "H"
#     }
#   ],
#   "object": {
#     "neo": true,
#     "orbit_id": "71",
#     "spkid": "20480883",
#     "kind": "an",
#     "pha": true,
#     "fullname": "480883 (2001 YE4)",
#     "orbit_class": {
#       "name": "Aten",
#       "code": "ATE"
#     },
#     "prefix": null,
#     "des": "480883"
#   }
# }
# Wrote raw object for 480883
# : spkid=20480883, des=480883
# {
#   "phys_par": [
#     {
#       "ref": "MPO745323",
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "value": "20.43",
#       "title": "absolute magnitude",
#       "notes": null,
#       "sigma": null,
#       "units": null,
#       "name": "H"
#     },
#     {
#       "value": "0.3",
#       "ref": "Hazards due to Comets and Asteroids (1994), Ed. T. Gehrels, pp.540-543",
#       "desc": "effective body diameter",
#       "title": "diameter",
#       "notes": "based on assumed medium albedo (0.15)",
#       "units": "km",
#       "sigma": null,
#       "name": "diameter"
#     },
#     {
#       "value": "3.35",
#       "desc": "body rotation period (synodic)",
#       "ref": "LCDB (Rev. 2023-October); Warner et al., 2009",
#       "notes": "REFERENCE LIST:[Pravec, P.; Wolf, M.; Sarounova, L. (2014) http://www.asu.cas.cz/~ppravec/neo.htm], [Warner, B.D. (2015) Minor Planet Bull. 42, 115-127.]",
#       "title": "rotation period",
#       "units": "h",
#       "sigma": null,
#       "name": "rot_per"
#     },
#     {
#       "name": "BV",
#       "units": null,
#       "sigma": "0.020",
#       "title": "B-V",
#       "notes": "#obs=1; phase=32.11 deg.",
#       "value": "0.770",
#       "ref": "EAR-A-5-DDR-UBV-MEAN-VALUES-V1.2",
#       "desc": "color index B-V magnitude difference"
#     },
#     {
#       "units": null,
#       "sigma": "0.042",
#       "name": "UB",
#       "value": "0.500",
#       "desc": "color index U-B magnitude difference",
#       "ref": "EAR-A-5-DDR-UBV-MEAN-VALUES-V1.2",
#       "notes": "#obs=1; phase=32.11 deg.",
#       "title": "U-B"
#     },
#     {
#       "ref": "EAR-A-5-DDR-TAXONOMY-V4.0",
#       "desc": "Tholen spectral taxonomic classification",
#       "value": "CSU",
#       "title": "Tholen spectral type",
#       "notes": "used 2 color indices",
#       "sigma": null,
#       "units": null,
#       "name": "spec_T"
#     },
#     {
#       "value": "Sq",
#       "ref": "EAR-A-5-DDR-TAXONOMY-V4.0",
#       "desc": "SMASSII spectral taxonomic classification",
#       "title": "SMASSII spectral type",
#       "notes": "based on a high-resolution spectrum by Xu et al. (1995) or Bus and Binzel (2002)",
#       "units": null,
#       "sigma": null,
#       "name": "spec_B"
#     }
#   ],
#   "object": {
#     "fullname": "2340 Hathor (1976 UA)",
#     "kind": "an",
#     "pha": true,
#     "des": "2340",
#     "orbit_class": {
#       "code": "ATE",
#       "name": "Aten"
#     },
#     "prefix": null,
#     "neo": true,
#     "shortname": "2340 Hathor",
#     "spkid": "20002340",
#     "orbit_id": "62"
#   },
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "orbit": {
#     "elements": [
#       {
#         "title": "eccentricity",
#         "name": "e",
#         "label": "e",
#         "units": null,
#         "value": "0.45",
#         "sigma": "3.6e-08"
#       },
#       {
#         "label": "a",
#         "name": "a",
#         "title": "semi-major axis",
#         "sigma": "1e-09",
#         "value": "0.844",
#         "units": "au"
#       },
#       {
#         "sigma": "3.1e-08",
#         "value": "0.464",
#         "units": "au",
#         "label": "q",
#         "title": "perihelion distance",
#         "name": "q"
#       },
#       {
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i",
#         "label": "i",
#         "value": "5.86",
#         "units": "deg",
#         "sigma": "4.3e-06"
#       },
#       {
#         "name": "om",
#         "title": "longitude of the ascending node",
#         "label": "node",
#         "units": "deg",
#         "value": "211",
#         "sigma": "1.4e-05"
#       },
#       {
#         "value": "40.1",
#         "units": "deg",
#         "sigma": "1.4e-05",
#         "name": "w",
#         "title": "argument of perihelion",
#         "label": "peri"
#       },
#       {
#         "name": "ma",
#         "title": "mean anomaly",
#         "label": "M",
#         "value": "202",
#         "units": "deg",
#         "sigma": "7.2e-06"
#       },
#       {
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp",
#         "value": "2461124.784",
#         "units": "TDB",
#         "sigma": "5.8e-06"
#       },
#       {
#         "units": "d",
#         "value": "283",
#         "sigma": "5e-07",
#         "title": "sidereal orbital period",
#         "name": "per",
#         "label": "period"
#       },
#       {
#         "sigma": "2.3e-09",
#         "units": "deg/d",
#         "value": "1.27",
#         "label": "n",
#         "name": "n",
#         "title": "mean motion"
#       },
#       {
#         "name": "ad",
#         "title": "aphelion distance",
#         "label": "Q",
#         "units": "au",
#         "value": "1.22",
#         "sigma": "1.5e-09"
#       }
#     ],
#     "not_valid_before": null,
#     "pe_used": "DE441",
#     "soln_date": "2022-12-20 16:03:51",
#     "data_arc": "16477",
#     "moid": "0.00663",
#     "last_obs": "2021-12-05",
#     "model_pars": [
#       {
#         "name": "A2",
#         "units": "au/d^2",
#         "sigma": "6.336E-16",
#         "n": 1,
#         "title": "non-grav. transverse accel.",
#         "kind": "EST",
#         "value": "-2.96e-14",
#         "desc": "non-gravitational transverse acceleration parameter"
#       },
#       {
#         "value": "1.",
#         "desc": "normalizing factor [default 0.1112620426]",
#         "title": "normalizing factor",
#         "n": 0,
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "ALN"
#       },
#       {
#         "kind": "SET",
#         "title": "non-grav. model exp. k",
#         "n": 0,
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "name": "NK",
#         "sigma": null,
#         "units": null
#       },
#       {
#         "sigma": null,
#         "units": null,
#         "name": "NM",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "value": "2.",
#         "kind": "SET",
#         "n": 0,
#         "title": "non-grav. model exp. m"
#       },
#       {
#         "name": "R0",
#         "units": "au",
#         "sigma": null,
#         "n": 0,
#         "title": "normalizing distance",
#         "kind": "SET",
#         "value": "1.",
#         "desc": "normalizing distance, au [default 2.808 au]"
#       }
#     ],
#     "n_del_obs_used": 4,
#     "cov_epoch": "2458035.5",
#     "equinox": "J2000",
#     "source": "JPL",
#     "not_valid_after": null,
#     "condition_code": "0",
#     "two_body": null,
#     "first_obs": "1976-10-25",
#     "t_jup": "6.882",
#     "n_obs_used": 572,
#     "rms": "0.37",
#     "comment": null,
#     "n_dop_obs_used": 3,
#     "epoch": "2461000.5",
#     "producer": "Giorgini",
#     "orbit_id": "62",
#     "moid_jup": "3.81",
#     "sb_used": "SB441-N16"
#   }
# }
# Wrote raw object for 2340
# : spkid=20002340, des=2340
# {
#   "phys_par": [
#     {
#       "name": "H",
#       "notes": null,
#       "value": "20.54",
#       "sigma": null,
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "title": "absolute magnitude",
#       "units": null,
#       "ref": "MPO701386"
#     },
#     {
#       "title": "rotation period",
#       "ref": "LCDB (Rev. 2023-October); Warner et al., 2009",
#       "units": "h",
#       "desc": "body rotation period (synodic)",
#       "notes": "REFERENCE LIST:[Pravec, P.; Wolf, M.; Sarounova, L. (2002) http://www.asu.cas.cz/~ppravec/neo.htm], [Hicks, M.; Mayes, D.; Barajas, T. (2010) Astronomer's Telegram 3073. http://www.astronomerstelegram.org], [Skiff, B.A.; McLelland, K.P.; Sanborn, J.; Pravec, P.; Koehn, B.W. (2019). Minor Planet Bull. 46, 458-503.]",
#       "value": "13.5",
#       "sigma": null,
#       "name": "rot_per"
#     }
#   ],
#   "object": {
#     "prefix": null,
#     "fullname": "524522 Zoozve (2002 VE68)",
#     "kind": "an",
#     "des": "524522",
#     "spkid": "20524522",
#     "pha": true,
#     "neo": true,
#     "orbit_id": "86",
#     "shortname": "524522 Zoozve",
#     "orbit_class": {
#       "name": "Aten",
#       "code": "ATE"
#     }
#   },
#   "orbit": {
#     "producer": "Otto Matic",
#     "soln_date": "2023-09-25 06:27:52",
#     "comment": null,
#     "data_arc": "7622",
#     "n_dop_obs_used": 6,
#     "rms": "0.29",
#     "orbit_id": "86",
#     "two_body": null,
#     "moid_jup": "3.96",
#     "n_del_obs_used": 4,
#     "source": "JPL",
#     "epoch": "2461000.5",
#     "moid": "0.0259",
#     "sb_used": "SB441-N16",
#     "first_obs": "2002-11-11",
#     "t_jup": "7.863",
#     "n_obs_used": 610,
#     "last_obs": "2023-09-24",
#     "model_pars": [
#       {
#         "sigma": "1.122E-15",
#         "n": 1,
#         "value": "-5.827e-14",
#         "name": "A2",
#         "kind": "EST",
#         "units": "au/d^2",
#         "title": "non-grav. transverse accel.",
#         "desc": "non-gravitational transverse acceleration parameter"
#       },
#       {
#         "n": 0,
#         "value": "1.",
#         "sigma": null,
#         "kind": "SET",
#         "name": "ALN",
#         "title": "normalizing factor",
#         "units": null,
#         "desc": "normalizing factor [default 0.1112620426]"
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "units": null,
#         "title": "non-grav. model exp. k",
#         "name": "NK",
#         "kind": "SET",
#         "sigma": null,
#         "value": "0.",
#         "n": 0
#       },
#       {
#         "kind": "SET",
#         "name": "NM",
#         "n": 0,
#         "value": "2.",
#         "sigma": null,
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "title": "non-grav. model exp. m",
#         "units": null
#       },
#       {
#         "kind": "SET",
#         "name": "R0",
#         "value": "1.",
#         "n": 0,
#         "sigma": null,
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "title": "normalizing distance",
#         "units": "au"
#       }
#     ],
#     "condition_code": "0",
#     "cov_epoch": "2457177.5",
#     "pe_used": "DE441",
#     "not_valid_before": null,
#     "equinox": "J2000",
#     "not_valid_after": null,
#     "elements": [
#       {
#         "name": "e",
#         "label": "e",
#         "units": null,
#         "sigma": "1.4e-08",
#         "title": "eccentricity",
#         "value": "0.41"
#       },
#       {
#         "title": "semi-major axis",
#         "value": "0.724",
#         "sigma": "8.3e-10",
#         "units": "au",
#         "label": "a",
#         "name": "a"
#       },
#       {
#         "label": "q",
#         "name": "q",
#         "value": "0.427",
#         "title": "perihelion distance",
#         "units": "au",
#         "sigma": "1e-08"
#       },
#       {
#         "sigma": "4.2e-06",
#         "units": "deg",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "value": "9.04",
#         "name": "i",
#         "label": "i"
#       },
#       {
#         "value": "231",
#         "title": "longitude of the ascending node",
#         "sigma": "5.3e-06",
#         "units": "deg",
#         "label": "node",
#         "name": "om"
#       },
#       {
#         "value": "355",
#         "title": "argument of perihelion",
#         "units": "deg",
#         "sigma": "9.3e-06",
#         "label": "peri",
#         "name": "w"
#       },
#       {
#         "sigma": "1.9e-05",
#         "units": "deg",
#         "value": "329",
#         "title": "mean anomaly",
#         "name": "ma",
#         "label": "M"
#       },
#       {
#         "sigma": "1.2e-05",
#         "units": "TDB",
#         "title": "time of perihelion passage",
#         "value": "2461020.139",
#         "name": "tp",
#         "label": "tp"
#       },
#       {
#         "name": "per",
#         "label": "period",
#         "sigma": "3.9e-07",
#         "units": "d",
#         "title": "sidereal orbital period",
#         "value": "225"
#       },
#       {
#         "units": "deg/d",
#         "sigma": "2.8e-09",
#         "title": "mean motion",
#         "value": "1.6",
#         "name": "n",
#         "label": "n"
#       },
#       {
#         "name": "ad",
#         "label": "Q",
#         "units": "au",
#         "sigma": "1.2e-09",
#         "title": "aphelion distance",
#         "value": "1.02"
#       }
#     ]
#   },
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   }
# }
# Wrote raw object for 524522
# : spkid=20524522, des=524522
# {
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "phys_par": [
#     {
#       "name": "H",
#       "sigma": null,
#       "units": null,
#       "notes": null,
#       "title": "absolute magnitude",
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "ref": "E2022C57",
#       "value": "22.62"
#     },
#     {
#       "title": "diameter",
#       "notes": null,
#       "value": "0.152",
#       "ref": "urn:nasa:pds:neowise_diameters_albedos::2.0[neos] (http://adsabs.harvard.edu/abs/2014ApJ...784..110M)",
#       "desc": "effective body diameter",
#       "name": "diameter",
#       "units": "km",
#       "sigma": "0.003"
#     },
#     {
#       "desc": "geometric albedo",
#       "ref": "urn:nasa:pds:neowise_diameters_albedos::2.0[neos] (http://adsabs.harvard.edu/abs/2014ApJ...784..110M)",
#       "value": "0.100",
#       "notes": null,
#       "title": "geometric albedo",
#       "sigma": "0.021",
#       "units": null,
#       "name": "albedo"
#     }
#   ],
#   "object": {
#     "fullname": "(2002 BF25)",
#     "kind": "au",
#     "pha": false,
#     "des": "2002 BF25",
#     "orbit_class": {
#       "name": "Apollo",
#       "code": "APO"
#     },
#     "prefix": null,
#     "neo": true,
#     "spkid": "3102784",
#     "orbit_id": "56"
#   },
#   "orbit": {
#     "sb_used": "SB441-N16",
#     "moid_jup": "4.11",
#     "first_obs": "2002-01-25",
#     "two_body": null,
#     "condition_code": "0",
#     "not_valid_after": null,
#     "orbit_id": "56",
#     "producer": "Otto Matic",
#     "epoch": "2461000.5",
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "n_dop_obs_used": 0,
#     "n_obs_used": 147,
#     "rms": "0.41",
#     "t_jup": "5.723",
#     "cov_epoch": "2456291.5",
#     "n_del_obs_used": 4,
#     "model_pars": [
#       {
#         "value": "1.663e-13",
#         "desc": "non-gravitational transverse acceleration parameter",
#         "n": 1,
#         "title": "non-grav. transverse accel.",
#         "kind": "EST",
#         "units": "au/d^2",
#         "sigma": "3.409E-15",
#         "name": "A2"
#       },
#       {
#         "value": "1.",
#         "desc": "normalizing factor [default 0.1112620426]",
#         "title": "normalizing factor",
#         "n": 0,
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "ALN"
#       },
#       {
#         "kind": "SET",
#         "title": "non-grav. model exp. k",
#         "n": 0,
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "name": "NK",
#         "sigma": null,
#         "units": null
#       },
#       {
#         "name": "NM",
#         "sigma": null,
#         "units": null,
#         "kind": "SET",
#         "n": 0,
#         "title": "non-grav. model exp. m",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "value": "2."
#       },
#       {
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "value": "1.",
#         "kind": "SET",
#         "n": 0,
#         "title": "normalizing distance",
#         "sigma": null,
#         "units": "au",
#         "name": "R0"
#       }
#     ],
#     "source": "JPL",
#     "equinox": "J2000",
#     "soln_date": "2022-12-20 14:11:02",
#     "pe_used": "DE441",
#     "not_valid_before": null,
#     "elements": [
#       {
#         "sigma": "2.1e-08",
#         "value": "0.222",
#         "units": null,
#         "label": "e",
#         "title": "eccentricity",
#         "name": "e"
#       },
#       {
#         "sigma": "3.1e-09",
#         "units": "au",
#         "value": "1.07",
#         "label": "a",
#         "title": "semi-major axis",
#         "name": "a"
#       },
#       {
#         "name": "q",
#         "title": "perihelion distance",
#         "label": "q",
#         "value": "0.837",
#         "units": "au",
#         "sigma": "2.2e-08"
#       },
#       {
#         "value": "6.31",
#         "units": "deg",
#         "sigma": "7.5e-06",
#         "name": "i",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "label": "i"
#       },
#       {
#         "value": "306",
#         "units": "deg",
#         "sigma": "1e-05",
#         "name": "om",
#         "title": "longitude of the ascending node",
#         "label": "node"
#       },
#       {
#         "sigma": "1e-05",
#         "units": "deg",
#         "value": "77.9",
#         "label": "peri",
#         "title": "argument of perihelion",
#         "name": "w"
#       },
#       {
#         "label": "M",
#         "name": "ma",
#         "title": "mean anomaly",
#         "sigma": "9.6e-06",
#         "units": "deg",
#         "value": "223"
#       },
#       {
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp",
#         "value": "2461155.012",
#         "units": "TDB",
#         "sigma": "1.1e-05"
#       },
#       {
#         "sigma": "1.8e-06",
#         "units": "d",
#         "value": "407",
#         "label": "period",
#         "title": "sidereal orbital period",
#         "name": "per"
#       },
#       {
#         "value": "0.885",
#         "units": "deg/d",
#         "sigma": "3.9e-09",
#         "title": "mean motion",
#         "name": "n",
#         "label": "n"
#       },
#       {
#         "label": "Q",
#         "title": "aphelion distance",
#         "name": "ad",
#         "sigma": "3.8e-09",
#         "value": "1.31",
#         "units": "au"
#       }
#     ],
#     "last_obs": "2022-02-04",
#     "moid": "0.0191",
#     "data_arc": "7315"
#   }
# }
# Wrote raw object for 2002 BF25
# : spkid=3102784, des=2002 BF25
# {
#   "object": {
#     "prefix": null,
#     "des": "2012 UR158",
#     "kind": "au",
#     "fullname": "(2012 UR158)",
#     "spkid": "3614980",
#     "pha": true,
#     "orbit_id": "31",
#     "neo": true,
#     "orbit_class": {
#       "code": "APO",
#       "name": "Apollo"
#     }
#   },
#   "phys_par": [
#     {
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "units": null,
#       "ref": "E2022W37",
#       "title": "absolute magnitude",
#       "name": "H",
#       "sigma": null,
#       "notes": null,
#       "value": "20.67"
#     },
#     {
#       "desc": "effective body diameter",
#       "units": "km",
#       "ref": "urn:nasa:pds:neowise_diameters_albedos::2.0[neos] (http://adsabs.harvard.edu/abs/2017AJ....154..168M)",
#       "title": "diameter",
#       "name": "diameter",
#       "sigma": "0.309",
#       "value": "0.629",
#       "notes": null
#     },
#     {
#       "value": "0.023",
#       "notes": null,
#       "sigma": "0.048",
#       "name": "albedo",
#       "title": "geometric albedo",
#       "ref": "urn:nasa:pds:neowise_diameters_albedos::2.0[neos] (http://adsabs.harvard.edu/abs/2017AJ....154..168M)",
#       "units": null,
#       "desc": "geometric albedo"
#     }
#   ],
#   "orbit": {
#     "sb_used": "SB441-N16",
#     "first_obs": "2012-10-22",
#     "source": "JPL",
#     "moid": "0.00121",
#     "epoch": "2461000.5",
#     "n_del_obs_used": null,
#     "moid_jup": "0.895",
#     "two_body": null,
#     "orbit_id": "31",
#     "rms": "0.42",
#     "n_dop_obs_used": null,
#     "data_arc": "3679",
#     "comment": null,
#     "soln_date": "2024-12-09 15:59:32",
#     "producer": "Otto Matic",
#     "elements": [
#       {
#         "title": "eccentricity",
#         "value": "0.858",
#         "sigma": "3.3e-08",
#         "units": null,
#         "label": "e",
#         "name": "e"
#       },
#       {
#         "value": "2.23",
#         "title": "semi-major axis",
#         "sigma": "1.4e-07",
#         "units": "au",
#         "label": "a",
#         "name": "a"
#       },
#       {
#         "name": "q",
#         "label": "q",
#         "sigma": "8.3e-08",
#         "units": "au",
#         "value": "0.317",
#         "title": "perihelion distance"
#       },
#       {
#         "units": "deg",
#         "sigma": "6.3e-06",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "value": "3.19",
#         "name": "i",
#         "label": "i"
#       },
#       {
#         "sigma": "0.00017",
#         "units": "deg",
#         "title": "longitude of the ascending node",
#         "value": "286",
#         "name": "om",
#         "label": "node"
#       },
#       {
#         "value": "239",
#         "title": "argument of perihelion",
#         "units": "deg",
#         "sigma": "0.00017",
#         "label": "peri",
#         "name": "w"
#       },
#       {
#         "title": "mean anomaly",
#         "value": "310",
#         "units": "deg",
#         "sigma": "3.3e-05",
#         "label": "M",
#         "name": "ma"
#       },
#       {
#         "units": "TDB",
#         "sigma": "0.00013",
#         "value": "2461168.769",
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp"
#       },
#       {
#         "sigma": "0.00011",
#         "units": "d",
#         "title": "sidereal orbital period",
#         "value": "1220",
#         "name": "per",
#         "label": "period"
#       },
#       {
#         "value": "0.296",
#         "title": "mean motion",
#         "sigma": "2.7e-08",
#         "units": "deg/d",
#         "label": "n",
#         "name": "n"
#       },
#       {
#         "name": "ad",
#         "label": "Q",
#         "sigma": "2.5e-07",
#         "units": "au",
#         "value": "4.15",
#         "title": "aphelion distance"
#       }
#     ],
#     "equinox": "J2000",
#     "not_valid_after": null,
#     "not_valid_before": null,
#     "pe_used": "DE441",
#     "cov_epoch": "2457877.5",
#     "condition_code": "0",
#     "model_pars": [
#       {
#         "sigma": "1.715E-13",
#         "n": 1,
#         "value": "-6.942e-12",
#         "kind": "EST",
#         "name": "A2",
#         "units": "au/d^2",
#         "title": "non-grav. transverse accel.",
#         "desc": "non-gravitational transverse acceleration parameter"
#       }
#     ],
#     "last_obs": "2022-11-18",
#     "n_obs_used": 139,
#     "t_jup": "3.004"
#   },
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   }
# }
# Wrote raw object for 2012 UR158
# : spkid=3614980, des=2012 UR158
# {
#   "object": {
#     "prefix": null,
#     "kind": "an",
#     "fullname": "523599 (2003 RM)",
#     "des": "523599",
#     "spkid": "20523599",
#     "pha": false,
#     "neo": true,
#     "orbit_id": "74",
#     "orbit_class": {
#       "name": "Amor",
#       "code": "AMO"
#     }
#   },
#   "phys_par": [
#     {
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "title": "absolute magnitude",
#       "units": null,
#       "ref": "MPO780436",
#       "name": "H",
#       "value": "19.64",
#       "notes": null,
#       "sigma": null
#     }
#   ],
#   "orbit": {
#     "t_jup": "2.955",
#     "last_obs": "2023-12-08",
#     "n_obs_used": 372,
#     "condition_code": "0",
#     "cov_epoch": "2458355.5",
#     "pe_used": "DE441",
#     "model_pars": [
#       {
#         "sigma": "2.984E-14",
#         "n": 1,
#         "value": "3.287e-12",
#         "kind": "EST",
#         "name": "A2",
#         "units": "au/d^2",
#         "title": "non-grav. transverse accel.",
#         "desc": "non-gravitational transverse acceleration parameter"
#       }
#     ],
#     "elements": [
#       {
#         "sigma": "2.6e-08",
#         "units": null,
#         "title": "eccentricity",
#         "value": "0.606",
#         "name": "e",
#         "label": "e"
#       },
#       {
#         "label": "a",
#         "name": "a",
#         "value": "2.91",
#         "title": "semi-major axis",
#         "sigma": "9.7e-09",
#         "units": "au"
#       },
#       {
#         "label": "q",
#         "name": "q",
#         "value": "1.15",
#         "title": "perihelion distance",
#         "units": "au",
#         "sigma": "7.5e-08"
#       },
#       {
#         "name": "i",
#         "label": "i",
#         "units": "deg",
#         "sigma": "3.4e-06",
#         "value": "11",
#         "title": "inclination; angle with respect to x-y ecliptic plane"
#       },
#       {
#         "value": "336",
#         "title": "longitude of the ascending node",
#         "units": "deg",
#         "sigma": "9.7e-06",
#         "label": "node",
#         "name": "om"
#       },
#       {
#         "name": "w",
#         "label": "peri",
#         "sigma": "1.1e-05",
#         "units": "deg",
#         "value": "325",
#         "title": "argument of perihelion"
#       },
#       {
#         "label": "M",
#         "name": "ma",
#         "title": "mean anomaly",
#         "value": "172",
#         "units": "deg",
#         "sigma": "2.9e-06"
#       },
#       {
#         "units": "TDB",
#         "sigma": "1.2e-05",
#         "value": "2460132.955",
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp"
#       },
#       {
#         "name": "per",
#         "label": "period",
#         "units": "d",
#         "sigma": "9.1e-06",
#         "title": "sidereal orbital period",
#         "value": "1820"
#       },
#       {
#         "value": "0.198",
#         "title": "mean motion",
#         "sigma": "9.9e-10",
#         "units": "deg/d",
#         "label": "n",
#         "name": "n"
#       },
#       {
#         "title": "aphelion distance",
#         "value": "4.68",
#         "sigma": "1.6e-08",
#         "units": "au",
#         "label": "Q",
#         "name": "ad"
#       }
#     ],
#     "equinox": "J2000",
#     "not_valid_after": null,
#     "not_valid_before": null,
#     "producer": "Otto Matic",
#     "soln_date": "2024-01-07 05:32:52",
#     "n_dop_obs_used": null,
#     "rms": "0.46",
#     "data_arc": "7402",
#     "comment": null,
#     "n_del_obs_used": null,
#     "moid_jup": "0.759",
#     "two_body": null,
#     "orbit_id": "74",
#     "source": "JPL",
#     "epoch": "2461000.5",
#     "moid": "0.161",
#     "sb_used": "SB441-N16",
#     "first_obs": "2003-09-02"
#   },
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   }
# }
# Wrote raw object for 523599
# : spkid=20523599, des=523599
# {
#   "orbit": {
#     "rms": "0.46",
#     "n_obs_used": 80,
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "n_dop_obs_used": null,
#     "t_jup": "6.517",
#     "producer": "Otto Matic",
#     "orbit_id": "22",
#     "epoch": "2461000.5",
#     "not_valid_after": null,
#     "condition_code": "1",
#     "two_body": null,
#     "first_obs": "2000-03-03",
#     "moid_jup": "3.91",
#     "sb_used": "SB441-N16",
#     "moid": "0.0306",
#     "data_arc": "8041",
#     "last_obs": "2022-03-09",
#     "not_valid_before": null,
#     "elements": [
#       {
#         "title": "eccentricity",
#         "name": "e",
#         "label": "e",
#         "value": "0.496",
#         "units": null,
#         "sigma": "2.9e-06"
#       },
#       {
#         "value": "0.896",
#         "units": "au",
#         "sigma": "9.3e-09",
#         "name": "a",
#         "title": "semi-major axis",
#         "label": "a"
#       },
#       {
#         "value": "0.452",
#         "units": "au",
#         "sigma": "2.6e-06",
#         "name": "q",
#         "title": "perihelion distance",
#         "label": "q"
#       },
#       {
#         "sigma": "7.6e-05",
#         "value": "11.6",
#         "units": "deg",
#         "label": "i",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i"
#       },
#       {
#         "title": "longitude of the ascending node",
#         "name": "om",
#         "label": "node",
#         "units": "deg",
#         "value": "163",
#         "sigma": "2.4e-05"
#       },
#       {
#         "label": "peri",
#         "title": "argument of perihelion",
#         "name": "w",
#         "sigma": "0.00011",
#         "units": "deg",
#         "value": "140"
#       },
#       {
#         "sigma": "0.00018",
#         "value": "35.3",
#         "units": "deg",
#         "label": "M",
#         "title": "mean anomaly",
#         "name": "ma"
#       },
#       {
#         "label": "tp",
#         "name": "tp",
#         "title": "time of perihelion passage",
#         "sigma": "0.00015",
#         "value": "2460970.116",
#         "units": "TDB"
#       },
#       {
#         "label": "period",
#         "title": "sidereal orbital period",
#         "name": "per",
#         "sigma": "4.8e-06",
#         "units": "d",
#         "value": "310"
#       },
#       {
#         "units": "deg/d",
#         "value": "1.16",
#         "sigma": "1.8e-08",
#         "title": "mean motion",
#         "name": "n",
#         "label": "n"
#       },
#       {
#         "units": "au",
#         "value": "1.34",
#         "sigma": "1.4e-08",
#         "title": "aphelion distance",
#         "name": "ad",
#         "label": "Q"
#       }
#     ],
#     "pe_used": "DE441",
#     "soln_date": "2022-12-20 14:10:52",
#     "equinox": "J2000",
#     "source": "JPL",
#     "model_pars": [
#       {
#         "name": "A2",
#         "units": "au/d^2",
#         "sigma": "8.163E-15",
#         "n": 1,
#         "title": "non-grav. transverse accel.",
#         "kind": "EST",
#         "value": "-2.71e-13",
#         "desc": "non-gravitational transverse acceleration parameter"
#       },
#       {
#         "desc": "normalizing factor [default 0.1112620426]",
#         "value": "1.",
#         "kind": "SET",
#         "n": 0,
#         "title": "normalizing factor",
#         "sigma": null,
#         "units": null,
#         "name": "ALN"
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "kind": "SET",
#         "title": "non-grav. model exp. k",
#         "n": 0,
#         "sigma": null,
#         "units": null,
#         "name": "NK"
#       },
#       {
#         "sigma": null,
#         "units": null,
#         "name": "NM",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "value": "2.",
#         "kind": "SET",
#         "title": "non-grav. model exp. m",
#         "n": 0
#       },
#       {
#         "name": "R0",
#         "sigma": null,
#         "units": "au",
#         "kind": "SET",
#         "title": "normalizing distance",
#         "n": 0,
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "value": "1."
#       }
#     ],
#     "cov_epoch": "2458168.5",
#     "n_del_obs_used": null
#   },
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "phys_par": [
#     {
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "ref": "MPO686041",
#       "value": "23.43",
#       "notes": null,
#       "title": "absolute magnitude",
#       "sigma": null,
#       "units": null,
#       "name": "H"
#     },
#     {
#       "name": "rot_per",
#       "units": "h",
#       "sigma": null,
#       "notes": "[Result based on less than full coverage, so that the period may be wrong by 30 percent or so.]  REFERENCE LIST:[Whiteley, R.J.; Tholen, D.J. (2000) Bull. Amer. Astron. Soc. 32, 1003.], [Whiteley, R.J.; Tholen, D.J.; Hergenrother, C.W. (2002) Icarus 157, 139-154.]",
#       "title": "rotation period",
#       "value": "1.79",
#       "desc": "body rotation period (synodic)",
#       "ref": "LCDB (Rev. 2023-October); Warner et al., 2009"
#     }
#   ],
#   "object": {
#     "neo": true,
#     "spkid": "3031176",
#     "orbit_id": "22",
#     "fullname": "(2000 EB14)",
#     "pha": false,
#     "kind": "au",
#     "des": "2000 EB14",
#     "prefix": null,
#     "orbit_class": {
#       "name": "Aten",
#       "code": "ATE"
#     }
#   }
# }
# Wrote raw object for 2000 EB14
# : spkid=3031176, des=2000 EB14
# {
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   },
#   "orbit": {
#     "moid_jup": "4.34",
#     "n_del_obs_used": 0,
#     "two_body": null,
#     "orbit_id": "57",
#     "sb_used": "SB441-N16",
#     "first_obs": "2005-03-09",
#     "source": "JPL",
#     "moid": "0.0515",
#     "epoch": "2461000.5",
#     "soln_date": "2025-03-17 05:47:23",
#     "producer": "Otto Matic",
#     "rms": "0.45",
#     "n_dop_obs_used": 1,
#     "data_arc": "7312",
#     "comment": null,
#     "cov_epoch": "2458292.5",
#     "pe_used": "DE441",
#     "condition_code": "0",
#     "model_pars": [
#       {
#         "units": "au/d^2",
#         "title": "non-grav. transverse accel.",
#         "desc": "non-gravitational transverse acceleration parameter",
#         "sigma": "2.878E-15",
#         "n": 1,
#         "value": "-1.384e-13",
#         "kind": "EST",
#         "name": "A2"
#       },
#       {
#         "units": null,
#         "title": "normalizing factor",
#         "desc": "normalizing factor [default 0.1112620426]",
#         "sigma": null,
#         "n": 0,
#         "value": "1.",
#         "name": "ALN",
#         "kind": "SET"
#       },
#       {
#         "units": null,
#         "title": "non-grav. model exp. k",
# ...
#       "value": "0.26",
#       "ref": "Hazards due to Comets and Asteroids (1994), Ed. T. Gehrels, pp.540-543",
#       "desc": "geometric albedo",
#       "title": "geometric albedo",
#       "notes": null
#     },
#     {
#       "notes": "#obs=1; phase=59.82 deg.",
#       "title": "B-V",
#       "desc": "color index B-V magnitude difference",
#       "ref": "EAR-A-5-DDR-UBV-MEAN-VALUES-V1.2",
#       "value": "0.930",
#       "name": "BV",
#       "sigma": "0.020",
#       "units": null
#     },
#     {
#       "name": "UB",
#       "sigma": "0.040",
#       "units": null,
#       "notes": "#obs=1; phase=59.82 deg.",
#       "title": "U-B",
#       "desc": "color index U-B magnitude difference",
#       "ref": "EAR-A-5-DDR-UBV-MEAN-VALUES-V1.2",
#       "value": "0.460"
#     },
#     {
#       "title": "Tholen spectral type",
#       "notes": "used 2 color indices; used ground-based radiometric albedo",
#       "ref": "EAR-A-5-DDR-TAXONOMY-V4.0",
#       "desc": "Tholen spectral taxonomic classification",
#       "value": "S",
#       "name": "spec_T",
#       "sigma": null,
#       "units": null
#     },
#     {
#       "ref": "EAR-A-5-DDR-TAXONOMY-V4.0",
#       "desc": "SMASSII spectral taxonomic classification",
#       "value": "Sr",
#       "title": "SMASSII spectral type",
#       "notes": "based on a high-resolution spectrum by Xu et al. (1995) or Bus and Binzel (2002)",
#       "sigma": null,
#       "units": null,
#       "name": "spec_B"
#     }
#   ],
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "orbit": {
#     "epoch": "2461000.5",
#     "producer": "Giorgini",
#     "orbit_id": "149",
#     "t_jup": "6.183",
#     "n_obs_used": 1024,
#     "rms": "0.35",
#     "n_dop_obs_used": 2,
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "two_body": null,
#     "first_obs": "1955-12-17",
#     "not_valid_after": null,
#     "condition_code": "0",
#     "moid_jup": "3.92",
#     "sb_used": "SB441-N16",
#     "last_obs": "2019-11-10",
#     "data_arc": "23339",
#     "moid": "0.113",
#     "pe_used": "DE441",
#     "soln_date": "2021-05-24 18:22:09",
#     "elements": [
#       {
#         "value": "0.183",
#         "units": null,
#         "sigma": "1.4e-09",
#         "title": "eccentricity",
#         "name": "e",
#         "label": "e"
#       },
#       {
#         "units": "au",
#         "value": "0.967",
#         "sigma": "1.1e-09",
#         "name": "a",
#         "title": "semi-major axis",
#         "label": "a"
#       },
#       {
#         "label": "q",
#         "title": "perihelion distance",
#         "name": "q",
#         "sigma": "1.3e-09",
#         "units": "au",
#         "value": "0.79"
#       },
#       {
#         "sigma": "7.1e-07",
#         "value": "18.9",
#         "units": "deg",
#         "label": "i",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i"
#       },
#       {
#         "sigma": "1.4e-06",
#         "units": "deg",
#         "value": "109",
#         "label": "node",
#         "name": "om",
#         "title": "longitude of the ascending node"
#       },
#       {
#         "name": "w",
#         "title": "argument of perihelion",
#         "label": "peri",
#         "value": "148",
#         "units": "deg",
#         "sigma": "1.7e-06"
#       },
#       {
#         "title": "mean anomaly",
#         "name": "ma",
#         "label": "M",
#         "units": "deg",
#         "value": "32.6",
#         "sigma": "5.9e-06"
#       },
#       {
#         "title": "time of perihelion passage",
#         "name": "tp",
#         "label": "tp",
#         "value": "2460969.013",
#         "units": "TDB",
#         "sigma": "5.6e-06"
#       },
#       {
#         "label": "period",
#         "title": "sidereal orbital period",
#         "name": "per",
#         "sigma": "5.7e-07",
#         "units": "d",
#         "value": "347"
#       },
#       {
#         "label": "n",
#         "name": "n",
#         "title": "mean motion",
#         "sigma": "1.7e-09",
#         "units": "deg/d",
#         "value": "1.04"
#       },
#       {
#         "title": "aphelion distance",
#         "name": "ad",
#         "label": "Q",
#         "units": "au",
#         "value": "1.14",
#         "sigma": "1.2e-09"
#       }
#     ],
#     "not_valid_before": null,
#     "source": "JPL",
#     "equinox": "J2000",
#     "n_del_obs_used": 5,
#     "cov_epoch": "2456625.5",
#     "model_pars": [
#       {
#         "name": "A2",
#         "sigma": "1.147E-15",
#         "units": "au/d^2",
#         "kind": "EST",
#         "title": "non-grav. transverse accel.",
#         "n": 1,
#         "desc": "non-gravitational transverse acceleration parameter",
#         "value": "-1.061e-14"
#       },
#       {
#         "value": "1.",
#         "desc": "normalizing factor [default 0.1112620426]",
#         "n": 0,
#         "title": "normalizing factor",
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "ALN"
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "kind": "SET",
#         "title": "non-grav. model exp. k",
#         "n": 0,
#         "sigma": null,
#         "units": null,
#         "name": "NK"
#       },
#       {
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "value": "2.",
#         "kind": "SET",
#         "n": 0,
#         "title": "non-grav. model exp. m",
#         "sigma": null,
#         "units": null,
#         "name": "NM"
#       },
#       {
#         "title": "normalizing distance",
#         "n": 0,
#         "kind": "SET",
#         "value": "1.",
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "name": "R0",
#         "units": "au",
#         "sigma": null
#       }
#     ]
#   }
# }
# Wrote raw object for 2062
# : spkid=20002062, des=2062
# {
#   "object": {
#     "orbit_id": "206",
#     "neo": true,
#     "orbit_class": {
#       "name": "Amor",
#       "code": "AMO"
#     },
#     "pha": false,
#     "spkid": "20010302",
#     "prefix": null,
#     "des": "10302",
#     "fullname": "10302 (1989 ML)",
#     "kind": "an"
#   },
#   "phys_par": [
#     {
#       "title": "absolute magnitude",
#       "units": null,
#       "ref": "E2025-UR3",
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "value": "19.44",
#       "notes": null,
#       "sigma": null,
#       "name": "H"
#     },
#     {
#       "desc": "body rotation period (synodic)",
#       "title": "rotation period",
#       "ref": "LCDB (Rev. 2023-October); Warner et al., 2009",
#       "units": "h",
#       "name": "rot_per",
#       "value": "19.2406",
#       "notes": "REFERENCE LIST:[Weissman, P.; Doressoundiram, A.; Hicks, M.; Chamberlin, A.; et al. (1999) Bull. Amer. Astron. Soc. 31, 1121.], [Abe, M.; Sato, I.; Araki, H. (2000) Adv. Space Res. 25, 269-272.], [Pravec, P.; Wolf, M.; Sarounova, L. (2019) http://www.asu.cas.cz/~ppravec/neo.htm], [Pravec, P.; Wolf, M.; Sarounova, L. (2022) http://www.asu.cas.cz/~ppravec/neo.htm], [Warner, B.D.; Stephens, R.D. (2022) Minor Plan. Bull. 49, 274-279.]",
#       "sigma": null
#     },
#     {
#       "desc": "SMASSII spectral taxonomic classification",
#       "title": "SMASSII spectral type",
#       "units": null,
#       "ref": "Binzel et al. (2001) Icarus 151, 139-149",
#       "name": "spec_B",
#       "notes": null,
#       "value": "X",
#       "sigma": null
#     }
#   ],
#   "orbit": {
#     "data_arc": "13298",
#     "rms": "0.47",
#     "n_dop_obs_used": null,
#     "comment": "Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2",
#     "soln_date": "2025-11-06 14:14:50",
#     "producer": "Otto Matic",
#     "sb_used": "SB441-N16",
#     "first_obs": "1989-06-06",
#     "source": "JPL",
#     "moid": "0.0805",
#     "epoch": "2461000.5",
#     "n_del_obs_used": null,
#     "moid_jup": "3.64",
#     "orbit_id": "206",
#     "two_body": null,
#     "n_obs_used": 1255,
#     "last_obs": "2025-11-02",
#     "t_jup": "5.065",
#     "not_valid_after": null,
#     "equinox": "J2000",
#     "elements": [
#       {
#         "label": "e",
#         "name": "e",
#         "title": "eccentricity",
#         "value": "0.137",
#         "units": null,
#         "sigma": "1.4e-08"
#       },
#       {
#         "label": "a",
#         "name": "a",
#         "value": "1.27",
#         "title": "semi-major axis",
#         "units": "au",
#         "sigma": "3e-09"
#       },
#       {
#         "label": "q",
#         "name": "q",
#         "title": "perihelion distance",
#         "value": "1.1",
#         "units": "au",
#         "sigma": "1.9e-08"
#       },
#       {
#         "name": "i",
#         "label": "i",
#         "units": "deg",
#         "sigma": "6.5e-07",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "value": "4.38"
#       },
#       {
#         "value": "104",
#         "title": "longitude of the ascending node",
#         "sigma": "1.2e-06",
#         "units": "deg",
#         "label": "node",
#         "name": "om"
#       },
#       {
#         "label": "peri",
#         "name": "w",
#         "value": "184",
#         "title": "argument of perihelion",
#         "units": "deg",
#         "sigma": "7.3e-06"
#       },
#       {
#         "units": "deg",
#         "sigma": "4e-06",
#         "title": "mean anomaly",
#         "value": "122",
#         "name": "ma",
#         "label": "M"
#       },
#       {
#         "label": "tp",
#         "name": "tp",
#         "title": "time of perihelion passage",
#         "value": "2460823.474",
#         "sigma": "6.2e-06",
#         "units": "TDB"
#       },
#       {
#         "value": "524",
#         "title": "sidereal orbital period",
#         "units": "d",
#         "sigma": "1.9e-06",
#         "label": "period",
#         "name": "per"
#       },
#       {
#         "units": "deg/d",
#         "sigma": "2.5e-09",
#         "title": "mean motion",
#         "value": "0.686",
#         "name": "n",
#         "label": "n"
#       },
#       {
#         "label": "Q",
#         "name": "ad",
#         "value": "1.45",
#         "title": "aphelion distance",
#         "units": "au",
#         "sigma": "3.4e-09"
#       }
#     ],
#     "not_valid_before": null,
#     "condition_code": "0",
#     "cov_epoch": "2458622.5",
#     "pe_used": "DE441",
#     "model_pars": [
#       {
#         "kind": "EST",
#         "name": "A2",
#         "sigma": "4.685E-15",
#         "value": "4.363e-14",
#         "n": 1,
#         "desc": "non-gravitational transverse acceleration parameter",
#         "units": "au/d^2",
#         "title": "non-grav. transverse accel."
#       },
#       {
#         "name": "ALN",
#         "kind": "SET",
#         "value": "1.",
#         "n": 0,
#         "sigma": null,
#         "desc": "normalizing factor [default 0.1112620426]",
#         "title": "normalizing factor",
#         "units": null
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "units": null,
#         "title": "non-grav. model exp. k",
#         "name": "NK",
#         "kind": "SET",
#         "sigma": null,
#         "value": "0.",
#         "n": 0
#       },
#       {
#         "title": "non-grav. model exp. m",
#         "units": null,
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "n": 0,
#         "value": "2.",
#         "sigma": null,
#         "kind": "SET",
#         "name": "NM"
#       },
#       {
#         "value": "1.",
#         "n": 0,
#         "sigma": null,
#         "kind": "SET",
#         "name": "R0",
#         "title": "normalizing distance",
#         "units": "au",
#         "desc": "normalizing distance, au [default 2.808 au]"
#       }
#     ]
#   },
#   "signature": {
#     "version": "1.3",
#     "source": "NASA/JPL Small-Body Database (SBDB) API"
#   }
# }
# Wrote raw object for 10302
# : spkid=20010302, des=10302
# {
#   "phys_par": [
#     {
#       "name": "H",
#       "sigma": null,
#       "units": null,
#       "notes": null,
#       "title": "absolute magnitude",
#       "desc": "absolute magnitude (magnitude at 1 au from Sun and observer)",
#       "ref": "MPO939804",
#       "value": "22.77"
#     }
#   ],
#   "object": {
#     "orbit_class": {
#       "name": "Amor",
#       "code": "AMO"
#     },
#     "prefix": null,
#     "des": "595116",
#     "kind": "an",
#     "pha": false,
#     "fullname": "595116 (2001 QE96)",
#     "orbit_id": "28",
#     "spkid": "20595116",
#     "neo": true
#   },
#   "signature": {
#     "source": "NASA/JPL Small-Body Database (SBDB) API",
#     "version": "1.3"
#   },
#   "orbit": {
#     "cov_epoch": "2458364.5",
#     "n_del_obs_used": null,
#     "model_pars": [
#       {
#         "name": "A2",
#         "sigma": "1.379E-14",
#         "units": "au/d^2",
#         "kind": "EST",
#         "title": "non-grav. transverse accel.",
#         "n": 1,
#         "desc": "non-gravitational transverse acceleration parameter",
#         "value": "-1.454e-13"
#       },
#       {
#         "value": "1.",
#         "desc": "normalizing factor [default 0.1112620426]",
#         "title": "normalizing factor",
#         "n": 0,
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "ALN"
#       },
#       {
#         "desc": "non-grav. model constant, exponent k [default 4.6142]",
#         "value": "0.",
#         "kind": "SET",
#         "n": 0,
#         "title": "non-grav. model exp. k",
#         "sigma": null,
#         "units": null,
#         "name": "NK"
#       },
#       {
#         "value": "2.",
#         "desc": "non-grav. model constant, exponent m [default 2.15]",
#         "n": 0,
#         "title": "non-grav. model exp. m",
#         "kind": "SET",
#         "units": null,
#         "sigma": null,
#         "name": "NM"
#       },
#       {
#         "desc": "normalizing distance, au [default 2.808 au]",
#         "value": "1.",
#         "kind": "SET",
#         "title": "normalizing distance",
#         "n": 0,
#         "sigma": null,
#         "units": "au",
#         "name": "R0"
#       }
#     ],
#     "source": "JPL",
#     "equinox": "J2000",
#     "soln_date": "2025-08-04 06:18:47",
#     "pe_used": "DE441",
#     "elements": [
#       {
#         "units": null,
#         "value": "0.0281",
#         "sigma": "1.6e-06",
#         "title": "eccentricity",
#         "name": "e",
#         "label": "e"
#       },
#       {
#         "name": "a",
#         "title": "semi-major axis",
#         "label": "a",
#         "value": "1.31",
#         "units": "au",
#         "sigma": "4.1e-09"
#       },
#       {
#         "sigma": "2.1e-06",
#         "value": "1.27",
#         "units": "au",
#         "label": "q",
#         "name": "q",
#         "title": "perihelion distance"
#       },
#       {
#         "value": "7.27",
#         "units": "deg",
#         "sigma": "1.9e-05",
#         "title": "inclination; angle with respect to x-y ecliptic plane",
#         "name": "i",
#         "label": "i"
#       },
#       {
#         "value": "150",
#         "units": "deg",
#         "sigma": "1.8e-05",
#         "title": "longitude of the ascending node",
#         "name": "om",
#         "label": "node"
#       },
#       {
#         "label": "peri",
#         "title": "argument of perihelion",
#         "name": "w",
#         "sigma": "0.0011",
#         "value": "279",
#         "units": "deg"
#       },
#       {
#         "title": "mean anomaly",
#         "name": "ma",
#         "label": "M",
#         "units": "deg",
#         "value": "320",
#         "sigma": "0.0012"
#       },
#       {
#         "label": "tp",
#         "name": "tp",
#         "title": "time of perihelion passage",
#         "sigma": "0.0018",
#         "units": "TDB",
#         "value": "2461061.038"
#       },
#       {
#         "title": "sidereal orbital period",
#         "name": "per",
#         "label": "period",
#         "units": "d",
#         "value": "548",
#         "sigma": "2.6e-06"
#       },
#       {
#         "title": "mean motion",
#         "name": "n",
#         "label": "n",
#         "units": "deg/d",
#         "value": "0.657",
#         "sigma": "3.1e-09"
#       },
#       {
#         "label": "Q",
#         "title": "aphelion distance",
#         "name": "ad",
#         "sigma": "4.2e-09",
#         "value": "1.35",
#         "units": "au"
#       }
#     ],
#     "not_valid_before": null,
#     "last_obs": "2025-08-03",
#     "data_arc": "8748",
#     "moid": "0.3",
#     "sb_used": "SB441-N16",
#     "moid_jup": "3.67",
#     "first_obs": "2001-08-21",
#     "two_body": null,
#     "condition_code": "0",
#     "not_valid_after": null,
#     "epoch": "2461000.5",
#     "orbit_id": "28",
#     "producer": "Otto Matic",
#     "t_jup": "4.965",
#     "n_dop_obs_used": null,
#     "comment": null,
#     "rms": "0.58",
#     "n_obs_used": 81
#   }
# }
# Wrote raw object for 595116
# : spkid=20595116, des=595116

# %%
import requests
import time
from typing import List, Dict, Any

# I'm going to beat up the person in charge of this API
def batch_query_asteroids(designations: List[str], batch_size: int = 10, delay: float = 1.0) -> List[Dict[str, Any]]:
    """
    Batch query asteroids from JPL SBDB API using IAU designations.
    
    Args:
        designations: List of asteroid IAU designations (e.g., ['Ceres', 'Pallas', 'Vesta'])
        batch_size: Number of asteroids to query in each API call (JPL recommends small batches)
        delay: Delay between requests in seconds to be respectful to the API
    
    Returns:
        List of asteroid data dictionaries
    """
    base_url = "https://ssd-api.jpl.nasa.gov/sbdb_query.api"
    results = []
    
    # Process in batches to avoid overwhelming the API
    for i in range(0, len(designations), batch_size):
        batch = designations[i:i + batch_size]
        
        # Create custom field constraint for IAU names
        names_constraint = '{"OR":' + '[' + ",".join(f'"sstr|RE|{name}"' for name in batch) + ']}'
        print(names_constraint)
        
        # Define the fields we want to retrieve
        params = {
            'fields': ','.join(identifier_params + crucial_orbital_params + physical_properties),
            'sb-cdata': names_constraint,
        }
        
        try:
            print(f"Querying batch {i//batch_size + 1}: {batch}")
            response = requests.get(base_url, params=params, timeout=30)
            response.raise_for_status()
            
            data = response.json()
            
            if 'data' in data and data['data']:
                # Map fields to data values
                for asteroid_data in data['data']:
                    asteroid_dict = dict(zip(data['fields'], asteroid_data))
                    results.append(asteroid_dict)
                    print(f"  ✓ Retrieved: {asteroid_dict.get('full_name', 'Unknown')}")
            else:
                print(f"  ⚠ No data returned for batch")
                
        except requests.exceptions.RequestException as e:
            print(f"  ✗ Error querying batch: {e}")
        except ValueError as e:
            print(f"  ✗ JSON parsing error: {e}")
        
        # Be respectful to the API - add delay between requests
        if i + batch_size < len(designations):
            print(f"Waiting {delay} seconds before next batch...")
            time.sleep(delay)
    
    return results


print("Starting batch query of asteroids...")
asteroids_data = batch_query_asteroids(
    designations=gaia_names[:10],
    batch_size=5,  # Small batches to be API-friendly
    delay=2.0      # 2 second delay between requests
)

print(f"\nQuery complete! Retrieved data for {len(asteroids_data)} asteroids.")
asteroids_data
# Out:
# Starting batch query of asteroids...
# {"OR":["sstr|RE|1998 SD9","sstr|RE|99942","sstr|RE|480883","sstr|RE|2340","sstr|RE|524522"]}
# Querying batch 1: ['1998 SD9', '99942', '480883', '2340', '524522']
#   ✗ Error querying batch: 400 Client Error: Bad Request for url: https://ssd-api.jpl.nasa.gov/sbdb_query.api?fields=full_name%2Cspkid%2Cneo%2Cpha%2Ca%2Ce%2Ci%2Cq%2Cad%2Cper%2Cn%2Cma%2CH%2Cdiameter%2Calbedo%2Crot_per%2CGM%2Cspec_B%2Cspec_T&sb-cdata=%7B%22OR%22%3A%5B%22sstr%7CRE%7C1998+SD9%22%2C%22sstr%7CRE%7C99942%22%2C%22sstr%7CRE%7C480883%22%2C%22sstr%7CRE%7C2340%22%2C%22sstr%7CRE%7C524522%22%5D%7D
# Waiting 2.0 seconds before next batch...
# {"OR":["sstr|RE|2002 BF25","sstr|RE|2012 UR158","sstr|RE|523599","sstr|RE|2000 EB14","sstr|RE|483656"]}
# Querying batch 2: ['2002 BF25', '2012 UR158', '523599', '2000 EB14', '483656']
#   ✗ Error querying batch: 400 Client Error: Bad Request for url: https://ssd-api.jpl.nasa.gov/sbdb_query.api?fields=full_name%2Cspkid%2Cneo%2Cpha%2Ca%2Ce%2Ci%2Cq%2Cad%2Cper%2Cn%2Cma%2CH%2Cdiameter%2Calbedo%2Crot_per%2CGM%2Cspec_B%2Cspec_T&sb-cdata=%7B%22OR%22%3A%5B%22sstr%7CRE%7C2002+BF25%22%2C%22sstr%7CRE%7C2012+UR158%22%2C%22sstr%7CRE%7C523599%22%2C%22sstr%7CRE%7C2000+EB14%22%2C%22sstr%7CRE%7C483656%22%5D%7D
#
# Query complete! Retrieved data for 0 asteroids.
# []

# %%
# test bulk query of 5
jpl_results = query_jpl_sbdb(gaia_names[:5], include_quality_metrics=False)
# Out:
# full_name,spkid,neo,pha,a,e,i,q,ad,per,n,ma,H,diameter,albedo,rot_per,GM,spec_B,spec_T
# Error: 400 - {"message":"bad character(s) in sb-cdata EQ argument for field 'name': check API document at https://ssd-api.jpl.nasa.gov/doc/sbdb_filter.html","code":"400"}

# %%
jpl_results_df = pandas.json_normalize(jpl_results)
jpl_results_df.head()
# Out:
#   orbit.source orbit.equinox  orbit.n_del_obs_used orbit.cov_epoch  \
# 0          JPL         J2000                    58       2455562.5
#
#                                     orbit.model_pars orbit.last_obs  \
# 0  [{'desc': 'solar radiation pressure area-to-ma...     2020-10-03
#
#   orbit.data_arc orbit.moid      orbit.soln_date orbit.pe_used  ...  \
# 0           7693    0.00322  2021-01-07 11:18:06         DE424  ...
#
#   object.des object.prefix object.orbit_class.code object.orbit_class.name  \
# 0     101955          None                     APO                  Apollo
#
#   object.neo object.spkid object.shortname object.orbit_id  \
# 0       True     20101955     101955 Bennu             118
#
#                           signature.source  signature.version
# 0  NASA/JPL Small-Body Database (SBDB) API                1.3
#
# [1 rows x 39 columns]

# %%
# Get drift column candidates for analysis from Gaia dataset
drift_candidates = gaia_data[['Asteroid', 'da_dt', 'e_da_dt', 'SNR', 'FAccept']] 
drift_candidates.head()
# Out:
#    Asteroid     da_dt   e_da_dt       SNR FAccept
# 0  1998 SD9 -0.019706  0.000106  185.3050       1
# 1     99942 -0.001326  0.000011  122.8940       1
# 2    480883 -0.005045  0.000053   94.6127       1
# 3      2340 -0.001738  0.000030   57.1118       1
# 4    524522 -0.003592  0.000063   56.9329       1
